# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Read CSV
abalone = pd.read_csv("abalone.csv")
print(abalone.shape)
abalone.info()
# Out:
# (4177, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
#Replace Rings with Age
abalone["Age"] = abalone["Rings"]+1.5
abalone.drop("Rings", axis=1, inplace = True)
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
#Check general stats
abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# ...

# %%
#Look for possible null in dataset
print(abalone.isnull().sum())
print(abalone.isna().sum())
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64

# %%
#Distribution of each column
abalone.hist(figsize=(20,10), grid=False, bins = 25)
plt.show()

# %%
#General Heatmap
plt.figure(figsize=(24,10))
sns.heatmap(abalone.corr(), annot=True)
plt.show()

# %%
#Heatmap visualized in graphs
sns.pairplot(abalone)
plt.show()

# %%
#Single comparisons with Age

#Length
plt.scatter(x = abalone["Length"], y = abalone["Age"])
plt.title("Length vs Age")
plt.show()
#Diameter
plt.scatter(x = abalone["Diameter"], y = abalone["Age"])
plt.title("Diameter vs Age")
plt.show()
#Height
plt.scatter(x = abalone["Height"], y = abalone["Age"])
plt.title("Height vs Age")
plt.show()
#Whole weight
plt.scatter(x = abalone["Whole weight"], y = abalone["Age"])
plt.title("Whole weight vs Age")
plt.show()
#Shucked weight
plt.scatter(x = abalone["Shucked weight"], y = abalone["Age"])
plt.title("Shucked weight vs Age")
plt.show()
#Viscera weight
plt.scatter(x = abalone["Viscera weight"], y = abalone["Age"])
plt.title("Viscera weight vs Age")
plt.show()
#Shell weight
plt.scatter(x = abalone["Shell weight"], y = abalone["Age"])
plt.title("Shell weight vs Age")
plt.show()

# %%
#Length vs Diameter
plt.scatter(x = abalone["Length"], y = abalone["Diameter"])
plt.title("Length vs Diameter")
plt.show()

# %%
sns.pairplot(abalone.filter(like="weight"))
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14,7))
sns.countplot(data=abalone, x="Sex", ax=ax[0])
plt.pie(abalone.value_counts("Sex"), labels=abalone.value_counts("Sex").index, autopct="%.1f%%")
plt.show()

# %%
#Comparing genders and infant
statsM = abalone[abalone["Sex"] == "M"].describe()
statsF = abalone[abalone["Sex"] == "F"].describe()
statsI = abalone[abalone["Sex"] == "I"].describe()
print("\033[1m" + "Male vs Female:\n" + "\033[0;0m" + "{}\n\n".format((statsM-statsF).loc["mean"][1:]) + 
      "\033[1m" + "Male vs Infant:\n" + "\033[0;0m" + "{}\n\n".format((statsM-statsI).loc["mean"][1:])  + 
      "\033[1m" + "Female vs Infant:\n" + "\033[0;0m" + "{}".format((statsF-statsI).loc["mean"][1:]))
# Out:
# Male vs Female:
# Diameter         -0.015446
# Height           -0.006630
# Whole weight     -0.055073
# Shucked weight   -0.013242
# Viscera weight   -0.015144
# Shell weight     -0.020041
# Age              -0.423806
# Name: mean, dtype: float64
#
# Male vs Infant:
# Diameter          0.112793
# Height            0.043385
# Whole weight      0.560097
# Shucked weight    0.241911
# Viscera weight    0.123534
# Shell weight      0.153787
# Age               2.815035
# Name: mean, dtype: float64
#
# Female vs Infant:
# Diameter          0.128238
# Height            0.050015
# Whole weight      0.615170
# Shucked weight    0.255153
# Viscera weight    0.138679
# Shell weight      0.173828
# Age               3.238842
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=abalone, x="Sex", y="Age", showfliers = False)
plt.show()

# %%
#Lower than normal Age correlation found in Males
plt.figure(figsize=(24,10))
sns.heatmap(abalone[abalone["Sex"] == "M"].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Far lower than normal Age correlation found in Females, also in Height
plt.figure(figsize=(24,10))
sns.heatmap(abalone[abalone["Sex"] == "F"].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Much stronger overall correlation found in infants: it becomes harder to estimate age as they grow older: diversification
plt.figure(figsize=(24,10))
sns.heatmap(abalone[abalone["Sex"] == "I"].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Heatmap with genders visualized
sns.pairplot(abalone, hue="Sex")

# %% [markdown]
# Corentin Individual Report

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %%
pred = abalone.copy(deep=True)
pred["Sex"] = pred["Sex"].replace(["I", "M", "F"],[0,1,2])

# %%
X = pred.drop(["Age"], axis=1).values
y = pred["Age"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
regressor = SVR()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
print("Training score: ", regressor.score(X_train, y_train))
print("Testing score: ", regressor.score(X_test, y_test))
# Out:
# Training score:  0.5638568831659634
# Testing score:  0.5235277983990154

# %%
offBy = 0.0
for i in range(len(pred)):
    offBy += 100*regressor.predict(sc.transform([pred.iloc[i][:-1]]))[0]/pred.iloc[i][-1]-100
offBy = offBy/len(pred)
print("Off by:", offBy)
# Out:
# Off by: -0.5044646702992233

# %%
abalone.iloc[:,:-1].boxplot( rot = 90, figsize=(20,5))
plt.show()

# %%
for i in range(3):
    pred = abalone.copy(deep=True)
    pred["Sex"] = pred["Sex"].replace(["I", "M", "F"],[0,1,2])
    pred = pred[pred["Sex"] == i]

    X = pred.drop(["Age"], axis=1).values
    y = pred["Age"].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)

    regressor = SVR()
    regressor.fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    print("Training score: ", regressor.score(X_train, y_train))
    print("Testing score: ", regressor.score(X_test, y_test))
# Out:
# Training score:  0.5975083645774959
# Testing score:  0.5180595938725971
# Training score:  0.44057454594908985
# Testing score:  0.42996226040637475
# Training score:  0.3466920874091598
# Testing score:  0.2907472433840591
